# %%
import os
import re
import numpy as np
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModel
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # --- Data Loading & Cleaning ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/datasets/final/medical_final_withId.csv')

# %%
"""
# extra cleaning i haven't tried it yet :/
def clean_text(text): ...
df['tokenized_text'] = df['description'].apply(clean_text)
"""
# Out:
# "\n# extra cleaning i haven't tried it yet :/\ndef clean_text(text): ...\ndf['tokenized_text'] = df['description'].apply(clean_text)\n"

# %% [markdown]
# ## Filtering out small classes (<90 entries):
# treating class embalance;
#
#
# ### TODO:
#
#   [ ] explore better strategies

# %%
min_samples = 90
df = df.groupby('Specialty').filter(lambda x: len(x) >= min_samples)
print(f"Filtered dataset shape: {df.shape}")
# Out:
# Filtered dataset shape: (18587, 6)

# %% [markdown]
# # --- Embedding Generation (Basic 1 layer CLS) ---

# %% [markdown]
# ### Remove any previously cached embeddings if they were generated on unfiltered data

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_size = 16
token_texts = df['tokenized_text'].tolist()

# %% [markdown]
# ## Load BioBERT with hidden states

# %%
model_name = 'emilyalsentzer/Bio_ClinicalBERT'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name, output_hidden_states=True)
model.to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(28996, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSdpaSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_size = 16
token_texts = df['tokenized_text'].tolist()

# %% [markdown]
# ## Extract the [CLS] token embeddings (first token of each sequence)

# %%
batch_size = 16
biobert_embeddings = []
num_batches = (len(df) + batch_size - 1) // batch_size
print(f"Generating BioBERT embeddings in {num_batches} batches...")

for i in range(0, len(df), batch_size):
    batch_texts = df['tokenized_text'][i:i+batch_size].tolist()
    encoded_inputs = tokenizer(batch_texts, padding=True, truncation=True, max_length=512, return_tensors="pt")
    encoded_inputs = {k: v.to(device) for k, v in encoded_inputs.items()}
    with torch.no_grad():
        outputs = model(**encoded_inputs)
    cls_embeddings = outputs.last_hidden_state[:, 0, :].cpu().numpy()
    biobert_embeddings.append(cls_embeddings)
    print(f"Processed batch {i//batch_size + 1}/{num_batches}")
# Out:
# Generating BioBERT embeddings in 1162 batches...
# Processed batch 1/1162
# Processed batch 2/1162
# Processed batch 3/1162
# Processed batch 4/1162
# Processed batch 5/1162
# Processed batch 6/1162
# Processed batch 7/1162
# Processed batch 8/1162
# Processed batch 9/1162
# Processed batch 10/1162
# Processed batch 11/1162
# Processed batch 12/1162
# Processed batch 13/1162
# Processed batch 14/1162
# Processed batch 15/1162
# Processed batch 16/1162
# Processed batch 17/1162
# Processed batch 18/1162
# Processed batch 19/1162
# Processed batch 20/1162
# Processed batch 21/1162
# Processed batch 22/1162
# Processed batch 23/1162
# Processed batch 24/1162
# Processed batch 25/1162
# Processed batch 26/1162
# Processed batch 27/1162
# Processed batch 28/1162
# Processed batch 29/1162
# Processed batch 30/1162
# Processed batch 31/1162
# Processed batch 32/1162
# Processed batch 33/1162
# Processed batch 34/1162
# Processed batch 35/1162
# Processed batch 36/1162
# Processed batch 37/1162
# Processed batch 38/1162
# Processed batch 39/1162
# Processed batch 40/1162
# Processed batch 41/1162
# Processed batch 42/1162
# Processed batch 43/1162
# Processed batch 44/1162
# Processed batch 45/1162
# Processed batch 46/1162
# Processed batch 47/1162
# Processed batch 48/1162
# Processed batch 49/1162
# Processed batch 50/1162
# Processed batch 51/1162
# Processed batch 52/1162
# Processed batch 53/1162
# Processed batch 54/1162
# Processed batch 55/1162
# Processed batch 56/1162
# Processed batch 57/1162
# Processed batch 58/1162
# Processed batch 59/1162
# Processed batch 60/1162
# Processed batch 61/1162
# Processed batch 62/1162
# Processed batch 63/1162
# Processed batch 64/1162
# Processed batch 65/1162
# Processed batch 66/1162
# Processed batch 67/1162
# Processed batch 68/1162
# Processed batch 69/1162
# Processed batch 70/1162
# Processed batch 71/1162
# Processed batch 72/1162
# Processed batch 73/1162
# Processed batch 74/1162
# Processed batch 75/1162
# Processed batch 76/1162
# Processed batch 77/1162
# Processed batch 78/1162
# Processed batch 79/1162
# Processed batch 80/1162
# Processed batch 81/1162
# Processed batch 82/1162
# Processed batch 83/1162
# Processed batch 84/1162
# Processed batch 85/1162
# Processed batch 86/1162
# Processed batch 87/1162
# Processed batch 88/1162
# Processed batch 89/1162
# Processed batch 90/1162
# Processed batch 91/1162
# Processed batch 92/1162
# Processed batch 93/1162
# Processed batch 94/1162
# Processed batch 95/1162
# Processed batch 96/1162
# Processed batch 97/1162
# Processed batch 98/1162
# Processed batch 99/1162
# Processed batch 100/1162
# Processed batch 101/1162
# Processed batch 102/1162
# Processed batch 103/1162
# Processed batch 104/1162
# Processed batch 105/1162
# Processed batch 106/1162
# Processed batch 107/1162
# Processed batch 108/1162
# Processed batch 109/1162
# Processed batch 110/1162
# Processed batch 111/1162
# Processed batch 112/1162
# Processed batch 113/1162
# Processed batch 114/1162
# Processed batch 115/1162
# Processed batch 116/1162
# Processed batch 117/1162
# Processed batch 118/1162
# Processed batch 119/1162
# Processed batch 120/1162
# Processed batch 121/1162
# Processed batch 122/1162
# Processed batch 123/1162
# Processed batch 124/1162
# Processed batch 125/1162
# Processed batch 126/1162
# Processed batch 127/1162
# Processed batch 128/1162
# Processed batch 129/1162
# Processed batch 130/1162
# Processed batch 131/1162
# Processed batch 132/1162
# Processed batch 133/1162
# Processed batch 134/1162
# Processed batch 135/1162
# Processed batch 136/1162
# Processed batch 137/1162
# Processed batch 138/1162
# Processed batch 139/1162
# Processed batch 140/1162
# Processed batch 141/1162
# Processed batch 142/1162
# Processed batch 143/1162
# Processed batch 144/1162
# Processed batch 145/1162
# Processed batch 146/1162
# Processed batch 147/1162
# Processed batch 148/1162
# Processed batch 149/1162
# Processed batch 150/1162
# Processed batch 151/1162
# Processed batch 152/1162
# Processed batch 153/1162
# Processed batch 154/1162
# Processed batch 155/1162
# Processed batch 156/1162
# Processed batch 157/1162
# Processed batch 158/1162
# Processed batch 159/1162
# Processed batch 160/1162
# Processed batch 161/1162
# Processed batch 162/1162
# Processed batch 163/1162
# Processed batch 164/1162
# Processed batch 165/1162
# Processed batch 166/1162
# Processed batch 167/1162
# Processed batch 168/1162
# Processed batch 169/1162
# Processed batch 170/1162
# Processed batch 171/1162
# Processed batch 172/1162
# Processed batch 173/1162
# Processed batch 174/1162
# Processed batch 175/1162
# Processed batch 176/1162
# Processed batch 177/1162
# Processed batch 178/1162
# Processed batch 179/1162
# Processed batch 180/1162
# Processed batch 181/1162
# Processed batch 182/1162
# Processed batch 183/1162
# Processed batch 184/1162
# Processed batch 185/1162
# Processed batch 186/1162
# Processed batch 187/1162
# Processed batch 188/1162
# Processed batch 189/1162
# Processed batch 190/1162
# Processed batch 191/1162
# Processed batch 192/1162
# Processed batch 193/1162
# Processed batch 194/1162
# Processed batch 195/1162
# Processed batch 196/1162
# Processed batch 197/1162
# Processed batch 198/1162
# Processed batch 199/1162
# Processed batch 200/1162
# Processed batch 201/1162
# Processed batch 202/1162
# Processed batch 203/1162
# Processed batch 204/1162
# Processed batch 205/1162
# Processed batch 206/1162
# Processed batch 207/1162
# Processed batch 208/1162
# Processed batch 209/1162
# Processed batch 210/1162
# Processed batch 211/1162
# Processed batch 212/1162
# Processed batch 213/1162
# Processed batch 214/1162
# Processed batch 215/1162
# Processed batch 216/1162
# Processed batch 217/1162
# Processed batch 218/1162
# Processed batch 219/1162
# Processed batch 220/1162
# Processed batch 221/1162
# Processed batch 222/1162
# Processed batch 223/1162
# Processed batch 224/1162
# Processed batch 225/1162
# Processed batch 226/1162
# Processed batch 227/1162
# Processed batch 228/1162
# Processed batch 229/1162
# Processed batch 230/1162
# Processed batch 231/1162
# Processed batch 232/1162
# Processed batch 233/1162
# Processed batch 234/1162
# Processed batch 235/1162
# Processed batch 236/1162
# Processed batch 237/1162
# Processed batch 238/1162
# Processed batch 239/1162
# Processed batch 240/1162
# Processed batch 241/1162
# Processed batch 242/1162
# Processed batch 243/1162
# Processed batch 244/1162
# Processed batch 245/1162
# Processed batch 246/1162
# Processed batch 247/1162
# Processed batch 248/1162
# Processed batch 249/1162
# Processed batch 250/1162
# Processed batch 251/1162
# Processed batch 252/1162
# Processed batch 253/1162
# Processed batch 254/1162
# Processed batch 255/1162
# Processed batch 256/1162
# Processed batch 257/1162
# Processed batch 258/1162
# Processed batch 259/1162
# Processed batch 260/1162
# Processed batch 261/1162
# Processed batch 262/1162
# Processed batch 263/1162
# Processed batch 264/1162
# Processed batch 265/1162
# Processed batch 266/1162
# Processed batch 267/1162
# Processed batch 268/1162
# Processed batch 269/1162
# Processed batch 270/1162
# Processed batch 271/1162
# Processed batch 272/1162
# Processed batch 273/1162
# Processed batch 274/1162
# Processed batch 275/1162
# Processed batch 276/1162
# Processed batch 277/1162
# Processed batch 278/1162
# Processed batch 279/1162
# Processed batch 280/1162
# Processed batch 281/1162
# Processed batch 282/1162
# Processed batch 283/1162
# Processed batch 284/1162
# Processed batch 285/1162
# Processed batch 286/1162
# Processed batch 287/1162
# Processed batch 288/1162
# Processed batch 289/1162
# Processed batch 290/1162
# Processed batch 291/1162
# Processed batch 292/1162
# Processed batch 293/1162
# Processed batch 294/1162
# Processed batch 295/1162
# Processed batch 296/1162
# Processed batch 297/1162
# Processed batch 298/1162
# Processed batch 299/1162
# Processed batch 300/1162
# Processed batch 301/1162
# Processed batch 302/1162
# Processed batch 303/1162
# Processed batch 304/1162
# Processed batch 305/1162
# Processed batch 306/1162
# Processed batch 572/1162
# Processed batch 573/1162
# Processed batch 574/1162
# Processed batch 575/1162
# Processed batch 576/1162
# Processed batch 577/1162
# Processed batch 578/1162
# Processed batch 579/1162
# Processed batch 580/1162
# Processed batch 581/1162
# Processed batch 582/1162
# Processed batch 583/1162
# Processed batch 584/1162
# Processed batch 585/1162
# Processed batch 586/1162
# Processed batch 587/1162
# Processed batch 588/1162
# Processed batch 589/1162
# Processed batch 590/1162
# Processed batch 591/1162
# Processed batch 592/1162
# Processed batch 593/1162
# Processed batch 594/1162
# Processed batch 595/1162
# Processed batch 596/1162
# Processed batch 597/1162
# Processed batch 598/1162
# Processed batch 599/1162
# Processed batch 600/1162
# Processed batch 601/1162
# Processed batch 602/1162
# Processed batch 603/1162
# Processed batch 604/1162
# Processed batch 605/1162
# Processed batch 606/1162
# Processed batch 607/1162
# Processed batch 608/1162
# Processed batch 609/1162
# Processed batch 610/1162
# Processed batch 611/1162
# Processed batch 612/1162
# Processed batch 613/1162
# Processed batch 614/1162
# Processed batch 615/1162
# Processed batch 616/1162
# Processed batch 617/1162
# Processed batch 618/1162
# Processed batch 619/1162
# Processed batch 620/1162
# Processed batch 621/1162
# Processed batch 622/1162
# Processed batch 623/1162
# Processed batch 624/1162
# Processed batch 625/1162
# Processed batch 626/1162
# Processed batch 627/1162
# Processed batch 628/1162
# Processed batch 629/1162
# Processed batch 630/1162
# Processed batch 631/1162
# Processed batch 632/1162
# Processed batch 633/1162
# Processed batch 634/1162
# Processed batch 635/1162
# Processed batch 636/1162
# Processed batch 637/1162
# Processed batch 638/1162
# Processed batch 639/1162
# Processed batch 640/1162
# Processed batch 641/1162
# Processed batch 642/1162
# Processed batch 643/1162
# Processed batch 644/1162
# Processed batch 645/1162
# Processed batch 646/1162
# Processed batch 647/1162
# Processed batch 648/1162
# Processed batch 649/1162
# Processed batch 650/1162
# Processed batch 651/1162
# Processed batch 652/1162
# Processed batch 653/1162
# Processed batch 654/1162
# Processed batch 655/1162
# Processed batch 656/1162
# Processed batch 657/1162
# Processed batch 658/1162
# Processed batch 659/1162
# Processed batch 660/1162
# Processed batch 661/1162
# Processed batch 662/1162
# Processed batch 663/1162
# Processed batch 664/1162
# Processed batch 665/1162
# Processed batch 666/1162
# Processed batch 667/1162
# Processed batch 668/1162
# Processed batch 669/1162
# Processed batch 670/1162
# Processed batch 671/1162
# Processed batch 672/1162
# Processed batch 673/1162
# Processed batch 674/1162
# Processed batch 675/1162
# Processed batch 676/1162
# Processed batch 677/1162
# Processed batch 678/1162
# Processed batch 679/1162
# Processed batch 680/1162
# Processed batch 681/1162
# Processed batch 682/1162
# Processed batch 683/1162
# Processed batch 684/1162
# Processed batch 685/1162
# Processed batch 686/1162
# Processed batch 687/1162
# Processed batch 688/1162
# Processed batch 689/1162
# Processed batch 690/1162
# Processed batch 691/1162
# Processed batch 692/1162
# Processed batch 693/1162
# Processed batch 694/1162
# Processed batch 695/1162
# Processed batch 696/1162
# Processed batch 697/1162
# Processed batch 698/1162
# Processed batch 699/1162
# Processed batch 700/1162
# Processed batch 701/1162
# Processed batch 702/1162
# Processed batch 703/1162
# Processed batch 704/1162
# Processed batch 705/1162
# Processed batch 706/1162
# Processed batch 707/1162
# Processed batch 708/1162
# Processed batch 709/1162
# Processed batch 710/1162
# Processed batch 711/1162
# Processed batch 712/1162
# Processed batch 713/1162
# Processed batch 714/1162
# Processed batch 715/1162
# Processed batch 716/1162
# Processed batch 717/1162
# Processed batch 718/1162
# Processed batch 719/1162
# Processed batch 720/1162
# Processed batch 721/1162
# Processed batch 722/1162
# Processed batch 723/1162
# Processed batch 724/1162
# Processed batch 725/1162
# Processed batch 726/1162
# Processed batch 727/1162
# Processed batch 728/1162
# Processed batch 729/1162
# Processed batch 730/1162
# Processed batch 731/1162
# Processed batch 732/1162
# Processed batch 733/1162
# Processed batch 734/1162
# Processed batch 735/1162
# Processed batch 736/1162
# Processed batch 737/1162
# Processed batch 738/1162
# Processed batch 739/1162
# Processed batch 740/1162
# Processed batch 741/1162
# Processed batch 742/1162
# Processed batch 743/1162
# Processed batch 744/1162
# Processed batch 745/1162
# Processed batch 746/1162
# Processed batch 747/1162
# Processed batch 748/1162
# Processed batch 749/1162
# Processed batch 750/1162
# Processed batch 751/1162
# Processed batch 752/1162
# Processed batch 753/1162
# Processed batch 754/1162
# Processed batch 755/1162
# Processed batch 756/1162
# Processed batch 757/1162
# Processed batch 758/1162
# Processed batch 759/1162
# Processed batch 760/1162
# Processed batch 761/1162
# Processed batch 762/1162
# Processed batch 763/1162
# Processed batch 764/1162
# Processed batch 765/1162
# Processed batch 766/1162
# Processed batch 767/1162
# Processed batch 768/1162
# Processed batch 769/1162
# Processed batch 770/1162
# Processed batch 771/1162
# Processed batch 772/1162
# Processed batch 773/1162
# Processed batch 774/1162
# Processed batch 775/1162
# Processed batch 776/1162
# Processed batch 777/1162
# Processed batch 778/1162
# Processed batch 779/1162
# Processed batch 780/1162
# Processed batch 781/1162
# Processed batch 782/1162
# Processed batch 783/1162
# Processed batch 784/1162
# Processed batch 785/1162
# Processed batch 786/1162
# Processed batch 787/1162
# Processed batch 788/1162
# Processed batch 789/1162
# Processed batch 790/1162
# Processed batch 791/1162
# Processed batch 792/1162
# Processed batch 793/1162
# Processed batch 794/1162
# Processed batch 795/1162
# Processed batch 796/1162
# Processed batch 797/1162
# Processed batch 798/1162
# Processed batch 799/1162
# Processed batch 800/1162
# Processed batch 801/1162
# Processed batch 802/1162
# Processed batch 803/1162
# Processed batch 804/1162
# Processed batch 805/1162
# Processed batch 806/1162
# Processed batch 807/1162
# Processed batch 808/1162
# Processed batch 809/1162
# Processed batch 810/1162
# Processed batch 811/1162
# Processed batch 812/1162
# Processed batch 813/1162
# Processed batch 814/1162
# Processed batch 815/1162
# Processed batch 816/1162
# Processed batch 817/1162
# Processed batch 818/1162
# Processed batch 819/1162
# Processed batch 820/1162
# Processed batch 821/1162
# Processed batch 822/1162
# Processed batch 823/1162
# Processed batch 824/1162
# Processed batch 825/1162
# Processed batch 826/1162
# Processed batch 827/1162
# Processed batch 828/1162
# Processed batch 829/1162
# Processed batch 830/1162
# Processed batch 831/1162
# Processed batch 832/1162
# Processed batch 833/1162
# Processed batch 834/1162
# Processed batch 835/1162
# Processed batch 1093/1162
# Processed batch 1094/1162
# Processed batch 1095/1162
# Processed batch 1096/1162
# Processed batch 1097/1162
# Processed batch 1098/1162
# Processed batch 1099/1162
# Processed batch 1100/1162
# Processed batch 1101/1162
# Processed batch 1102/1162
# Processed batch 1103/1162
# Processed batch 1104/1162
# Processed batch 1105/1162
# Processed batch 1106/1162
# Processed batch 1107/1162
# Processed batch 1108/1162
# Processed batch 1109/1162
# Processed batch 1110/1162
# Processed batch 1111/1162
# Processed batch 1112/1162
# Processed batch 1113/1162
# Processed batch 1114/1162
# Processed batch 1115/1162
# Processed batch 1116/1162
# Processed batch 1117/1162
# Processed batch 1118/1162
# Processed batch 1119/1162
# Processed batch 1120/1162
# Processed batch 1121/1162
# Processed batch 1122/1162
# Processed batch 1123/1162
# Processed batch 1124/1162
# Processed batch 1125/1162
# Processed batch 1126/1162
# Processed batch 1127/1162
# Processed batch 1128/1162
# Processed batch 1129/1162
# Processed batch 1130/1162
# Processed batch 1131/1162
# Processed batch 1132/1162
# Processed batch 1133/1162
# Processed batch 1134/1162
# Processed batch 1135/1162
# Processed batch 1136/1162
# Processed batch 1137/1162
# Processed batch 1138/1162
# Processed batch 1139/1162
# Processed batch 1140/1162
# Processed batch 1141/1162
# Processed batch 1142/1162
# Processed batch 1143/1162
# Processed batch 1144/1162
# Processed batch 1145/1162
# Processed batch 1146/1162
# Processed batch 1147/1162
# Processed batch 1148/1162
# Processed batch 1149/1162
# Processed batch 1150/1162
# Processed batch 1151/1162
# Processed batch 1152/1162
# Processed batch 1153/1162
# Processed batch 1154/1162
# Processed batch 1155/1162
# Processed batch 1156/1162
# Processed batch 1157/1162
# Processed batch 1158/1162
# Processed batch 1159/1162
# Processed batch 1160/1162
# Processed batch 1161/1162
# Processed batch 1162/1162

# %% [markdown]
# ## Saving the generated embeddings:

# %%
embedding_file = 'biobert_plain_embeddings.npy'
biobert_embeddings = np.vstack(biobert_embeddings)
np.save(embedding_file, biobert_embeddings)
print("BioBERT embeddings generated and saved.")
print(f"BioBERT embeddings shape: {biobert_embeddings.shape}")
# Out:
# BioBERT embeddings generated and saved.
# BioBERT embeddings shape: (18587, 768)

# %% [markdown]
# # Train/Validation/Test split

# %% [markdown]
# #### encoding labels (y's)

# %%
label_encoder = LabelEncoder()
df['specialty_encoded'] = label_encoder.fit_transform(df['Specialty'])
print("Label encoding sample:", dict(zip(label_encoder.classes_, range(len(label_encoder.classes_)))))


print(f"Number of samples in df: {len(df)}")
# Out:
# Label encoding sample: {'Cardiology': 0, 'Dentistry': 1, 'Dermatology': 2, 'ENT and Pulmonology': 3, 'Endocrinology': 4, 'Family Medicine': 5, 'Gastroenterology': 6, 'General Medicine': 7, 'Internal Medicine': 8, 'Neurology': 9, 'Obstetrics and Gynecology': 10, 'Ophthalmology': 11, 'Orthopedics and Traumatology': 12, 'Pediatrics': 13, 'Physiotherapy and Rehabilitation': 14, 'Psychology/Psychiatry': 15, 'Surgery': 16, 'Urology': 17}
# Number of samples in df: 18587

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(
    biobert_embeddings, df['specialty_encoded'], test_size=0.2, random_state=42, stratify=df['specialty_encoded']
)
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.25, random_state=42, stratify=y_train_val
)

print(f"Training set: {X_train.shape[0]} samples")
print(f"Validation set: {X_val.shape[0]} samples")
print(f"Test set: {X_test.shape[0]} samples")
# Out:
# Training set: 11151 samples
# Validation set: 3718 samples
# Test set: 3718 samples

# %% [markdown]
# # The classifier

# %% [markdown]
# ## COnstruction

# %%
input_dim = X_train.shape[1]
num_classes = len(label_encoder.classes_)

model_tf = models.Sequential([
    layers.Input(shape=(input_dim,)),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.4),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.2),
    layers.Dense(num_classes, activation='softmax')
])

model_tf.compile(
    optimizer=optimizers.Adam(learning_rate=1e-3),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model_tf.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │       393,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 18)             │         2,322 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 563,858 (2.15 MB)
#  Trainable params: 562,066 (2.14 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %% [markdown]
# ## Training

# %%
callbacks_list = [
    callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    callbacks.ModelCheckpoint('best_medical_classifier.keras', monitor='val_accuracy', save_best_only=True),
    callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
]

history = model_tf.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=32,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.5306 - loss: 1.7560 - val_accuracy: 0.6587 - val_loss: 1.0880 - learning_rate: 0.0010
# Epoch 2/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6547 - loss: 1.1427 - val_accuracy: 0.6877 - val_loss: 0.9948 - learning_rate: 0.0010
# Epoch 3/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6836 - loss: 1.0233 - val_accuracy: 0.6939 - val_loss: 0.9894 - learning_rate: 0.0010
# Epoch 4/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6901 - loss: 0.9807 - val_accuracy: 0.7063 - val_loss: 0.9502 - learning_rate: 0.0010
# Epoch 5/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7168 - loss: 0.9121 - val_accuracy: 0.7098 - val_loss: 0.9275 - learning_rate: 0.0010
# Epoch 6/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7156 - loss: 0.8877 - val_accuracy: 0.7249 - val_loss: 0.8913 - learning_rate: 0.0010
# Epoch 7/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7199 - loss: 0.8634 - val_accuracy: 0.7235 - val_loss: 0.8618 - learning_rate: 0.0010
# Epoch 8/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7258 - loss: 0.8338 - val_accuracy: 0.7281 - val_loss: 0.8798 - learning_rate: 0.0010
# Epoch 9/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7369 - loss: 0.7974 - val_accuracy: 0.7216 - val_loss: 0.8918 - learning_rate: 0.0010
# Epoch 10/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7444 - loss: 0.7804 - val_accuracy: 0.7205 - val_loss: 0.9036 - learning_rate: 0.0010
# Epoch 11/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7432 - loss: 0.7840 - val_accuracy: 0.7316 - val_loss: 0.8789 - learning_rate: 0.0010
# Epoch 12/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7525 - loss: 0.7637 - val_accuracy: 0.7310 - val_loss: 0.8662 - learning_rate: 0.0010
# Epoch 13/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7708 - loss: 0.7178 - val_accuracy: 0.7343 - val_loss: 0.8368 - learning_rate: 5.0000e-04
# Epoch 14/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7700 - loss: 0.6891 - val_accuracy: 0.7388 - val_loss: 0.8548 - learning_rate: 5.0000e-04
# Epoch 15/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7816 - loss: 0.6691 - val_accuracy: 0.7367 - val_loss: 0.8548 - learning_rate: 5.0000e-04
# Epoch 16/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7806 - loss: 0.6561 - val_accuracy: 0.7383 - val_loss: 0.8647 - learning_rate: 5.0000e-04
# Epoch 17/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7819 - loss: 0.6581 - val_accuracy: 0.7351 - val_loss: 0.8606 - learning_rate: 5.0000e-04
# Epoch 18/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7877 - loss: 0.6375 - val_accuracy: 0.7345 - val_loss: 0.8734 - learning_rate: 5.0000e-04
# Epoch 19/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7876 - loss: 0.6303 - val_accuracy: 0.7442 - val_loss: 0.8499 - learning_rate: 2.5000e-04
# Epoch 20/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7925 - loss: 0.6255 - val_accuracy: 0.7386 - val_loss: 0.8559 - learning_rate: 2.5000e-04
# Epoch 21/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8029 - loss: 0.6001 - val_accuracy: 0.7405 - val_loss: 0.8581 - learning_rate: 2.5000e-04
# Epoch 22/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8003 - loss: 0.5890 - val_accuracy: 0.7396 - val_loss: 0.8641 - learning_rate: 2.5000e-04
# Epoch 23/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8109 - loss: 0.5627 - val_accuracy: 0.7431 - val_loss: 0.8704 - learning_rate: 2.5000e-04

# %% [markdown]
# # --- Evaluation ---

# %% [markdown]
# Methode(s): we're calculating the accuracy / using a confusion matrix

# %%
test_loss, test_acc = model_tf.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}, loss: {test_loss:.4f}")
# Out:
# Test accuracy: 0.7539, loss: 0.7999

# %%
y_pred = np.argmax(model_tf.predict(X_test), axis=1)
target_names = label_encoder.classes_
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#                                   precision    recall  f1-score   support
#
#                       Cardiology       0.66      0.58      0.62        90
#                        Dentistry       0.84      0.88      0.86       136
#                      Dermatology       0.75      0.80      0.77       254
#              ENT and Pulmonology       0.51      0.47      0.49        75
#                    Endocrinology       0.57      0.41      0.48        49
#                  Family Medicine       0.96      0.77      0.86       356
#                 Gastroenterology       0.41      0.28      0.33        43
#                 General Medicine       0.66      0.75      0.70       455
#                Internal Medicine       0.36      0.29      0.32       318
#                        Neurology       0.73      0.87      0.79       247
#        Obstetrics and Gynecology       0.87      0.95      0.91       926
#                    Ophthalmology       0.91      0.75      0.82        68
#     Orthopedics and Traumatology       0.54      0.45      0.49        49
#                       Pediatrics       0.56      0.48      0.51        63
# Physiotherapy and Rehabilitation       0.54      0.25      0.34        28
#            Psychology/Psychiatry       0.89      0.89      0.89       465
#                          Surgery       0.00      0.00      0.00        23
#                          Urology       0.39      0.52      0.44        73
#
#                         accuracy                           0.75      3718
#                        macro avg       0.62      0.58      0.59      3718
#                     weighted avg       0.74      0.75      0.75      3718

# %% [markdown]
# ### *Confusion matrix fuss*

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()

# %%
# !ls
# Out:
# best_medical_classifier.keras  biobert_plain_embeddings.npy  drive  sample_data

# %%
# !mkdir drive/MyDrive/noyau2

# %%
# !cp biobert_plain_embeddings.npy drive/MyDrive/noyau2

# %%
# !cp best_medical_classifier.keras drive/MyDrive/noyau2

# %%
# !ls drive/MyDrive | grep noyau
# Out:
# noyau
# noyau2
# noyauS

# %%
# !rm drive/MyDrive/noyau2
